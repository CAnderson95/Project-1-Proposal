# %%
import pandas as pd
import json
import quandl

# %%
base_url = "https://www.quandl.com/data/ZILLOW/S28_MSPAH.json?api_key="
print(base_url)
# Out:
# https://www.quandl.com/data/ZILLOW/S28_MSPAH.json?api_key=

# %%
api_key = 'kTiBuUzNCs2XLbSjUgQ3'
response = base_url + api_key
print(response)
# Out:
# https://www.quandl.com/data/ZILLOW/S28_MSPAH.json?api_key=kTiBuUzNCs2XLbSjUgQ3

# %%
data = quandl.get("ZILLOW/S28_MSPAH", authtoken="kTiBuUzNCs2XLbSjUgQ3")
data
# Out:
#                Value
# Date
# 1996-04-30   96050.0
# 1996-05-31   97950.0
# 1996-06-30   99275.0
# 1996-07-31  100850.0
# 1996-08-31  100700.0
# ...              ...
# 2016-02-29  167300.0
# 2016-03-31  170400.0
# 2016-04-30  178100.0
# 2016-05-31  186325.0
# 2016-06-30  197025.0
#
# [243 rows x 1 columns]

# %%
data_df = pd.DataFrame(data)
data_df.head()
# Out:
#                Value
# Date
# 2010-01-31  199900.0
# 2010-02-28  199900.0
# 2010-03-31  199900.0
# 2010-04-30  199900.0
# 2010-05-31  199900.0

# %%
pd.set_option('display.max_rows', None)

# %%
print(data_df)
# Out:
#                Value
# Date
# 2010-01-31  199900.0
# 2010-02-28  199900.0
# 2010-03-31  199900.0
# 2010-04-30  199900.0
# 2010-05-31  199900.0
# 2010-06-30  199000.0
# 2010-07-31  198000.0
# 2010-08-31  194900.0
# 2010-09-30  192900.0
# 2010-10-31  194900.0
# 2010-11-30  194900.0
# 2010-12-31  189900.0
# 2011-01-31  187494.5
# 2011-02-28  185000.0
# 2011-03-31  187900.0
# 2011-04-30  189000.0
# 2011-05-31  189900.0
# 2011-06-30  189900.0
# 2011-07-31  189500.0
# 2011-08-31  189000.0
# 2011-09-30  187600.0
# 2011-10-31  186500.0
# 2011-11-30  185000.0
# 2011-12-31  182500.0
# 2012-01-31  181000.0
# 2012-02-29  182500.0
# 2012-03-31  185000.0
# 2012-04-30  185000.0
# 2012-05-31  184900.0
# 2012-06-30  184900.0
# 2012-07-31  181900.0
# 2012-08-31  182000.0
# 2012-09-30  179900.0
# 2012-10-31  179900.0
# 2012-11-30  179900.0
# 2012-12-31  179900.0
# 2013-01-31  179900.0
# 2013-02-28  184900.0
# 2013-03-31  188000.0
# 2013-04-30  189900.0
# 2013-05-31  194900.0
# 2013-06-30  199000.0
# ...

# %%
alamance = quandl.get("ZILLOW/CO1292_MVALFAH", authtoken="kTiBuUzNCs2XLbSjUgQ3")
alamance
# Out:
#             Value
# Date
# 1996-04-30   53.0
# 1996-05-31   53.0
# 1996-06-30   54.0
# 1996-07-31   54.0
# 1996-08-31   54.0
# ...           ...
# 2018-05-31   94.0
# 2018-06-30   95.0
# 2018-07-31   95.0
# 2018-08-31   97.0
# 2018-09-30   98.0
#
# [270 rows x 1 columns]

# %%
alexander = quandl.get("ZILLOW/CO721_MVALFAH", authtoken="kTiBuUzNCs2XLbSjUgQ3")
alexander
# Out:
#             Value
# Date
# 1996-04-30   49.0
# 1996-05-31   49.0
# 1996-06-30   49.0
# 1996-07-31   50.0
# 1996-08-31   50.0
# ...           ...
# 2018-05-31   98.0
# 2018-06-30   98.0
# 2018-07-31   99.0
# 2018-08-31  100.0
# 2018-09-30  101.0
#
# [270 rows x 1 columns]

# %%
alleghany = quandl.get("ZILLOW/CO4701_MVALFAH", authtoken="kTiBuUzNCs2XLbSjUgQ3")
alleghany
# Out:
#             Value
# Date
# 1999-10-31   67.0
# 1999-11-30   68.0
# 1999-12-31   68.0
# 2000-01-31   69.0
# 2000-02-29   69.0
# ...           ...
# 2019-11-30  120.0
# 2019-12-31  120.0
# 2020-01-31  121.0
# 2020-02-29  121.0
# 2020-03-31  121.0
#
# [246 rows x 1 columns]

# %%
anson = quandl.get("ZILLOW/CO825_MVALFAH", authtoken="kTiBuUzNCs2XLbSjUgQ3")
anson
# Out:
#             Value
# Date
# 1996-04-30   28.0
# 1996-05-31   27.0
# 1996-06-30   27.0
# 1996-07-31   27.0
# 1996-08-31   27.0
# ...           ...
# 2018-05-31   51.0
# 2018-06-30   51.0
# 2018-07-31   51.0
# 2018-08-31   51.0
# 2018-09-30   51.0
#
# [270 rows x 1 columns]

# %%
ashe = quandl.get("ZILLOW/CO4435_MVALFAH", authtoken="kTiBuUzNCs2XLbSjUgQ3")
ashe
# Out:
#             Value
# Date
# 1996-04-30  169.0
# 1996-05-31  170.0
# 1996-06-30  171.0
# 1996-07-31  172.0
# 1996-08-31  172.0
# ...           ...
# 2019-11-30  347.0
# 2019-12-31  348.0
# 2020-01-31  347.0
# 2020-02-29  347.0
# 2020-03-31  348.0
#
# [288 rows x 1 columns]

# %%
avery = quandl.get("ZILLOW/CO4618_MVALFAH", authtoken="kTiBuUzNCs2XLbSjUgQ3")
avery
# Out:
#             Value
# Date
# 2015-01-31  176.0
# 2015-02-28  176.0
# 2015-03-31  177.0
# 2015-04-30  177.0
# 2015-05-31  177.0
# ...           ...
# 2019-11-30  199.0
# 2019-12-31  201.0
# 2020-01-31  201.0
# 2020-02-29  203.0
# 2020-03-31  204.0
#
# [63 rows x 1 columns]
