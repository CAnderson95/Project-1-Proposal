# %%
import pandas as pd
from pprint import pprint

# %%
# types of data we want to pull (by county):
# median listing price
# decrease in value pct
# increase in value pct
# median price reduction
# inventory measure
# ZHVI summary, for better clarification see : https://www.zillow.com/research/why-zillow-home-value-index-better-17742/

# %%
# Dates to spread data analysis 1-2 years out on either side of:
# Obama second term: Jan-20-2013
# Trump first term: Jan-20-2017

# %%
county_median_listing_price_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/azp4mpneglvndiwze5nagg44l43w7v'))
county_median_listing_price_df
# Out:
#          RegionName State                           Metro  StateCodeFIPS  \
# 0       Los Angeles    CA  Los Angeles-Long Beach-Anaheim              6
# 1              Cook    IL                         Chicago             17
# 2            Harris    TX                         Houston             48
# 3          Maricopa    AZ                         Phoenix              4
# 4         San Diego    CA                       San Diego              6
# ...             ...   ...                             ...            ...
# 2284      Vega Baja    PR                        San Juan             72
# 2285     San German    PR            San German-Cabo Rojo             72
# 2286    Las Piedras    PR                        San Juan             72
# 2287    San Lorenzo    PR                        San Juan             72
# 2288  Trujillo Alto    PR                        San Juan             72
#
#       MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  \
# ...

# %%
county_decrease_value_pct_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/cc43xw52k5t4hfxuptjxrfbgbhqas4'))
county_decrease_value_pct_df
# Out:
#       RegionID   RegionName State                           Metro  \
# 0         3101  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 1          139         Cook    IL                         Chicago
# 2         2402     Maricopa    AZ                         Phoenix
# 3         2841    San Diego    CA                       San Diego
# 4         1286       Orange    CA  Los Angeles-Long Beach-Anaheim
# ...        ...          ...   ...                             ...
# 1150       474        Delta    TX                             NaN
# 1151       539        Grant    OK                             NaN
# 1152       665        Ouray    CO                             NaN
# 1153      2497     Red Lake    MN                             NaN
# 1154       828       Alpine    CA                             NaN
#
#       StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1997-02  1997-03  1997-04  \
# 0                 6                 37         1    48.56    46.10    42.89
# ...

# %%
county_median_price_reduction_pct_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/p5e5dtddvxttor4lty5xqooerh5db2'))
county_median_price_reduction_pct_df
# Out:
#       RegionID   RegionName State  SizeRank    2010-09    2010-10    2010-11  \
# 0         3101  Los Angeles    CA         1   4.999838   4.706990   4.656671
# 1          139         Cook    IL         2   4.962719   4.809619   5.000037
# 2         1090       Harris    TX         3   4.186768   4.159292   4.166667
# 3         2402     Maricopa    AZ         4   5.268704   5.010020   5.019942
# 4         2841    San Diego    CA         5   4.582235   4.264392   4.291845
# ...        ...          ...   ...       ...        ...        ...        ...
# 1447       752        Towns    GA      1655   7.671958   9.618639   7.977815
# 1448       910       Camden    NC      1660   7.215153   3.886867   4.264392
# 1449      1454       Valley    ID      1661   9.952381  10.007148   9.099181
# 1450      3106  Montmorency    MI      1662  11.953305   9.090150   9.204545
# 1451      2931   Grand Isle    VT      1670   6.712075   7.233333  12.698413
#
# ...

# %%
county_increase_value_pct_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/3dhnjnhbuctviu7zkkznu554jneorj'))
county_increase_value_pct_df
# Out:
#       RegionID   RegionName State                           Metro  \
# 0         3101  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 1          139         Cook    IL                         Chicago
# 2         2402     Maricopa    AZ                         Phoenix
# 3         2841    San Diego    CA                       San Diego
# 4         1286       Orange    CA  Los Angeles-Long Beach-Anaheim
# ...        ...          ...   ...                             ...
# 1150       474        Delta    TX                             NaN
# 1151       539        Grant    OK                             NaN
# 1152       665        Ouray    CO                             NaN
# 1153      2497     Red Lake    MN                             NaN
# 1154       828       Alpine    CA                             NaN
#
#       StateCodeFIPS  MunicipalCodeFIPS  SizeRank  1997-02  1997-03  1997-04  \
# 0                 6                 37         1    42.56    44.42    47.14
# ...

# %%
county_inventory_measure_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/sewl76vcb27jicrj76qnxz5mmhtmf2'))
county_inventory_measure_df
# Out:
#        RegionName RegionType   CountyName                           Metro  \
# 0     Los Angeles     County  Los Angeles  Los Angeles-Long Beach-Anaheim
# 1            Cook     County         Cook                         Chicago
# 2          Harris     County       Harris                         Houston
# 3        Maricopa     County     Maricopa                         Phoenix
# 4       San Diego     County    San Diego                       San Diego
# ...           ...        ...          ...                             ...
# 1844        Adams     County        Adams                             NaN
# 1845       Mercer     County       Mercer                             NaN
# 1846        Butte     County        Butte                     Idaho Falls
# 1847      Quitman     County      Quitman                             NaN
# 1848     San Juan     County     San Juan                             NaN
#
#      StateFullName DataTypeDescription  2010-01  2010-02  2010-03  2010-04  \
# ...

# %%
county_inventory_measure_ssa_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/7dgqivworhtluhkn264cg6pg4ildm6'))
county_inventory_measure_ssa_df
# Out:
#        RegionName RegionType   CountyName                           Metro  \
# 0     Los Angeles     County  Los Angeles  Los Angeles-Long Beach-Anaheim
# 1            Cook     County         Cook                         Chicago
# 2          Harris     County       Harris                         Houston
# 3        Maricopa     County     Maricopa                         Phoenix
# 4       San Diego     County    San Diego                       San Diego
# ...           ...        ...          ...                             ...
# 1844        Adams     County        Adams                             NaN
# 1845       Mercer     County       Mercer                             NaN
# 1846        Butte     County        Butte                     Idaho Falls
# 1847      Quitman     County      Quitman                             NaN
# 1848     San Juan     County     San Juan                             NaN
#
#      StateFullName DataTypeDescription  2010-01  2010-02  2010-03  2010-04  \
# ...

# %%
county_zhvi_summary_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/iwu242mxghpdhe6uagp64bssigieeg'))
county_zhvi_summary_df
# Out:
#             Date  RegionID   RegionName State                           Metro  \
# 0     2017-09-30      3101  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 1     2017-09-30       139         Cook    IL                         Chicago
# 2     2017-09-30      2402     Maricopa    AZ                         Phoenix
# 3     2017-09-30      2841    San Diego    CA                       San Diego
# 4     2017-09-30      1286       Orange    CA  Los Angeles-Long Beach-Anaheim
# ...          ...       ...          ...   ...                             ...
# 1701  2017-09-30       359        Adams    ND                             NaN
# 1702  2017-09-30       305         Rich    UT                             NaN
# 1703  2017-09-30       442        Clark    KS                             NaN
# 1704  2017-09-30      2220     Comanche    KS                             NaN
# 1705  2017-09-30       828       Alpine    CA                             NaN
#
# ...

# %%
merge_increase_decrease_value = county_decrease_value_pct_df.merge(county_increase_value_pct_df, how='outer', left_index=True, right_index=True)
merge_increase_decrease_value
# Out:
#       RegionID_x RegionName_x State_x                         Metro_x  \
# 0           3101  Los Angeles      CA  Los Angeles-Long Beach-Anaheim
# 1            139         Cook      IL                         Chicago
# 2           2402     Maricopa      AZ                         Phoenix
# 3           2841    San Diego      CA                       San Diego
# 4           1286       Orange      CA  Los Angeles-Long Beach-Anaheim
# ...          ...          ...     ...                             ...
# 1150         474        Delta      TX                             NaN
# 1151         539        Grant      OK                             NaN
# 1152         665        Ouray      CO                             NaN
# 1153        2497     Red Lake      MN                             NaN
# 1154         828       Alpine      CA                             NaN
#
#       StateCodeFIPS_x  MunicipalCodeFIPS_x  SizeRank_x  1997-02_x  1997-03_x  \
# ...

# %%
column_list = list(merge_increase_decrease_value)
column_list
# Out:
# ['RegionID_x',
#  'RegionName_x',
#  'State_x',
#  'Metro_x',
#  'StateCodeFIPS_x',
#  'MunicipalCodeFIPS_x',
#  'SizeRank_x',
#  '1997-02_x',
#  '1997-03_x',
#  '1997-04_x',
#  '1997-05_x',
#  '1997-06_x',
#  '1997-07_x',
#  '1997-08_x',
#  '1997-09_x',
#  '1997-10_x',
#  '1997-11_x',
#  '1997-12_x',
#  '1998-01_x',
#  '1998-02_x',
#  '1998-03_x',
#  '1998-04_x',
#  '1998-05_x',
#  '1998-06_x',
#  '1998-07_x',
#  '1998-08_x',
#  '1998-09_x',
#  '1998-10_x',
#  '1998-11_x',
#  '1998-12_x',
#  '1999-01_x',
#  '1999-02_x',
#  '1999-03_x',
#  '1999-04_x',
#  '1999-05_x',
#  '1999-06_x',
#  '1999-07_x',
#  '1999-08_x',
#  '1999-09_x',
#  '1999-10_x',
#  '1999-11_x',
#  '1999-12_x',
#  '2000-01_x',
#  '2000-02_x',
#  '2000-03_x',
#  '2000-04_x',
#  '2000-05_x',
#  '2000-06_x',
#  '2000-07_x',
#  '2000-08_x',
#  '2000-09_x',
#  '2000-10_x',
#  '2000-11_x',
#  '2000-12_x',
#  '2001-01_x',
#  '2001-02_x',
#  '2001-03_x',
#  '2001-04_x',
#  '2001-05_x',
#  '2001-06_x',
#  '2001-07_x',
# ...

# %%
# State Data Grabs

# %%
state_median_listing_price_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/dnbvyqky22ypxgwpobxmtxrzabna4l'))
state_median_listing_price_df
# Out:
#               RegionName  SizeRank     2010-01     2010-02     2010-03  \
# 0             California         1         NaN         NaN         NaN
# 1                  Texas         2   85.271318   85.712857   86.176113
# 2               New York         3  176.817770  171.645900  173.524306
# 3                Florida         4  117.785714  115.789474  113.788741
# 4               Illinois         5  130.147337  129.805195  130.503731
# 5           Pennsylvania         6  118.523080  118.796296  120.307988
# 6                   Ohio         7         NaN         NaN         NaN
# 7               Michigan         8   86.105477   86.239782   85.909091
# 8                Georgia         9   94.334251   94.248466   94.205841
# 9         North Carolina        10  110.156460  109.921799  110.000000
# 10            New Jersey        11  186.707292  187.125000  188.524590
# 11              Virginia        12  136.011905  135.869565  136.455044
# ...

# %%
state_median_price_reduction_pct_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/giahtzt7kepnf7hvmpplmwfidknhgi'))
state_median_price_reduction_pct_df
# Out:
#     RegionID            RegionName  SizeRank   2010-09   2010-10   2010-11  \
# 0          9            California         1  5.027652  4.884211  4.971429
# 1         54                 Texas         2  4.008016  3.968254  3.875289
# 2         43              New York         3  4.545455  4.412089  4.366812
# 3         14               Florida         4  6.666667  6.060606  5.918058
# 4         21              Illinois         5  4.761905  4.568528  4.761905
# 5         47          Pennsylvania         6  4.347826  4.174201  4.150035
# 6         44                  Ohio         7  5.025126  4.920635  5.000000
# 7         30              Michigan         8  7.168459  6.979991  7.147963
# 8         16               Georgia         9  6.060606  5.844544  5.889282
# 9         36        North Carolina        10  4.766444  4.545455  4.461440
# 10        40            New Jersey        11  4.761916  4.545455  4.625971
# ...

# %%
state_decrease_value_pct_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/3bc7jmhfh554mjv4ikivps34ejycfw'))
state_decrease_value_pct_df
# Out:
#     RegionID            RegionName  SizeRank  1997-02  1997-03  1997-04  \
# 0          9            California         1    43.66    41.88    40.51
# 1         43              New York         2    45.21    43.35    39.71
# 2         14               Florida         3    38.78    37.40    37.05
# 3         21              Illinois         4    40.00    35.90    38.16
# 4         47          Pennsylvania         5    43.04    42.00    43.05
# 5         44                  Ohio         6    26.04    26.09    26.08
# 6         30              Michigan         7    26.03    25.60    34.72
# 7         16               Georgia         8    28.46    28.55    27.48
# 8         36        North Carolina         9    26.05    26.21    29.09
# 9         40            New Jersey        10    42.41    42.38    38.51
# 10        56              Virginia        11    40.80    39.38    41.54
# 11        59            Washington        12    26.80    26.11    24.71
# ...

# %%
state_increase_value_pct_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/pryizs5itb2ilek6asdxvs5i5q5kea'))
state_increase_value_pct_df
# Out:
#     RegionID            RegionName  SizeRank  1997-02  1997-03  1997-04  \
# 0          9            California         1    48.12    49.55    50.72
# 1         43              New York         2    47.90    49.49    52.14
# 2         14               Florida         3    54.32    55.39    55.39
# 3         21              Illinois         4    52.02    55.83    52.86
# 4         47          Pennsylvania         5    48.76    49.26    48.01
# 5         44                  Ohio         6    65.86    65.90    65.81
# 6         30              Michigan         7    69.09    69.58    60.21
# 7         16               Georgia         8    63.38    62.98    64.13
# 8         36        North Carolina         9    66.83    66.52    63.39
# 9         40            New Jersey        10    49.96    49.88    53.25
# 10        56              Virginia        11    48.49    49.15    46.80
# 11        59            Washington        12    64.98    65.13    67.11
# ...

# %%
state_zhvi_summary_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/2w7itycnobznpfaiwxoa4iq3q6taam'))
state_zhvi_summary_df
# Out:
#           Date  RegionID            RegionName  SizeRank    Zhvi       MoM  \
# 0   2017-09-30    102001         United States         0  202700  0.004460
# 1   2017-09-30         9            California         1  509600  0.005326
# 2   2017-09-30        54                 Texas         2  170200  0.001766
# 3   2017-09-30        43              New York         3  304200  0.002637
# 4   2017-09-30        14               Florida         4  212100  0.006167
# 5   2017-09-30        21              Illinois         5  170200  0.003538
# 6   2017-09-30        47          Pennsylvania         6  161100  0.002489
# 7   2017-09-30        44                  Ohio         7  128700  0.001556
# 8   2017-09-30        30              Michigan         8  135300  0.003709
# 9   2017-09-30        16               Georgia         9  159100  0.006325
# 10  2017-09-30        36        North Carolina        10  163600  0.006150
# ...

# %%
state_inventory_measure_ssa_df = pd.DataFrame(pd.read_csv('https://query.data.world/s/pc7wzkbuvdyv7qhlo3bpz6iyx4h2rh'))
state_inventory_measure_ssa_df
# Out:
#               RegionName RegionType         StateFullName DataTypeDescription  \
# 0             California      State            California           All Homes
# 1                  Texas      State                 Texas           All Homes
# 2               New York      State              New York           All Homes
# 3                Florida      State               Florida           All Homes
# 4               Illinois      State              Illinois           All Homes
# 5           Pennsylvania      State          Pennsylvania           All Homes
# 6                   Ohio      State                  Ohio           All Homes
# 7               Michigan      State              Michigan           All Homes
# 8                Georgia      State               Georgia           All Homes
# 9         North Carolina      State        North Carolina           All Homes
# 10            New Jersey      State            New Jersey           All Homes
# ...
